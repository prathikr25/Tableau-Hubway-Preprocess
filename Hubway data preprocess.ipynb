# %%
import pandas as pd
stations=pd.read_csv("C:/Users/prathik/Documents/Data Science Super Specialization/Tableau/Project/hubway_stations.csv")

# %%
trips=pd.read_csv("C:/Users/prathik/Documents/Data Science Super Specialization/Tableau/Project/hubway_trips.csv")

# %%
trips.head()
# Out:
#    seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 0       1          8  Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9  Closed       220  7/28/2011 10:21:00        23.0
# 2       3         10  Closed        56  7/28/2011 10:33:00        23.0
# 3       4         11  Closed        64  7/28/2011 10:35:00        23.0
# 4       5         12  Closed        12  7/28/2011 10:37:00        23.0
#
#              end_date  end_statn bike_nr  subsc_type zip_code  birth_date  \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered   '97217      1976.0
# 1  7/28/2011 10:25:00       23.0  B00554  Registered   '02215      1966.0
# 2  7/28/2011 10:34:00       23.0  B00456  Registered   '02108      1943.0
# 3  7/28/2011 10:36:00       23.0  B00554  Registered   '02116      1981.0
# 4  7/28/2011 10:37:00       23.0  B00554  Registered   '97214      1983.0
#
#    gender
# 0    Male
# 1    Male
# 2    Male
# 3  Female
# 4  Female

# %%
result = pd.merge(trips,
                 stations,
                 left_on='strt_statn',right_on='id')
result['origin_destination']='origin'

# %%
result.head(2)
# Out:
#    seq_id  hubway_id status_x  duration          start_date strt_statn  \
# 0       1          8   Closed         9  7/28/2011 10:12:00         23
# 1       2          9   Closed       220  7/28/2011 10:21:00         23
#
#              end_date  end_statn bike_nr  subsc_type        ...          \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered        ...
# 1  7/28/2011 10:25:00       23.0  B00554  Registered        ...
#
#   birth_date  gender  id  terminal  \
# 0     1976.0    Male  23    B32008
# 1     1966.0    Male  23    B32008
#
#                                       station municipal        lat        lng  \
# 0  Mayor Thomas M. Menino - Government Center    Boston  42.359677 -71.059364
# 1  Mayor Thomas M. Menino - Government Center    Boston  42.359677 -71.059364
#
#    status_y origin_destination
# 0   Removed             origin
# 1   Removed             origin
#
# [2 rows x 21 columns]

# %%
result_1 = pd.merge(trips,
                 stations,
                 left_on='end_statn',right_on='id')
result_1['origin_destination']='destination'

# %%
result_1.head(2)
# Out:
#    seq_id  hubway_id status_x  duration          start_date  strt_statn  \
# 0       1          8   Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9   Closed       220  7/28/2011 10:21:00        23.0
#
#              end_date end_statn bike_nr  subsc_type        ...          \
# 0  7/28/2011 10:12:00        23  B00468  Registered        ...
# 1  7/28/2011 10:25:00        23  B00554  Registered        ...
#
#   birth_date  gender  id  terminal  \
# 0     1976.0    Male  23    B32008
# 1     1966.0    Male  23    B32008
#
#                                       station municipal        lat        lng  \
# 0  Mayor Thomas M. Menino - Government Center    Boston  42.359677 -71.059364
# 1  Mayor Thomas M. Menino - Government Center    Boston  42.359677 -71.059364
#
#    status_y origin_destination
# 0   Removed        destination
# 1   Removed        destination
#
# [2 rows x 21 columns]

# %%
final = pd.concat([result, result_1])

# %%
final.head(2)
# Out:
#    seq_id  hubway_id status_x  duration          start_date strt_statn  \
# 0       1          8   Closed         9  7/28/2011 10:12:00         23
# 1       2          9   Closed       220  7/28/2011 10:21:00         23
#
#              end_date end_statn bike_nr  subsc_type        ...          \
# 0  7/28/2011 10:12:00        23  B00468  Registered        ...
# 1  7/28/2011 10:25:00        23  B00554  Registered        ...
#
#   birth_date  gender  id  terminal  \
# 0     1976.0    Male  23    B32008
# 1     1966.0    Male  23    B32008
#
#                                       station municipal        lat        lng  \
# 0  Mayor Thomas M. Menino - Government Center    Boston  42.359677 -71.059364
# 1  Mayor Thomas M. Menino - Government Center    Boston  42.359677 -71.059364
#
#    status_y origin_destination
# 0   Removed             origin
# 1   Removed             origin
#
# [2 rows x 21 columns]

# %%
final.sort_values(by='seq_id')
# Out:
#           seq_id  hubway_id status_x  duration           start_date  \
# 0              1          8   Closed         9   7/28/2011 10:12:00
# 0              1          8   Closed         9   7/28/2011 10:12:00
# 1              2          9   Closed       220   7/28/2011 10:21:00
# 1              2          9   Closed       220   7/28/2011 10:21:00
# 2              3         10   Closed        56   7/28/2011 10:33:00
# 2              3         10   Closed        56   7/28/2011 10:33:00
# 3              4         11   Closed        64   7/28/2011 10:35:00
# 3              4         11   Closed        64   7/28/2011 10:35:00
# 4              5         12   Closed        12   7/28/2011 10:37:00
# 4              5         12   Closed        12   7/28/2011 10:37:00
# 5              6         13   Closed        19   7/28/2011 10:39:00
# 5              6         13   Closed        19   7/28/2011 10:39:00
# 6              7         14   Closed        24   7/28/2011 10:47:00
# 6              7         14   Closed        24   7/28/2011 10:47:00
# 7              8         15   Closed         7   7/28/2011 10:48:00
# 7              8         15   Closed         7   7/28/2011 10:48:00
# 8              9         16   Closed         8   7/28/2011 11:01:00
# 8              9         16   Closed         8   7/28/2011 11:01:00
# 11024         10         17   Closed      1108   7/28/2011 11:55:00
# 9843          10         17   Closed      1108   7/28/2011 11:55:00
# 11025         11         18   Closed      1055   7/28/2011 11:55:00
# 9844          11         18   Closed      1055   7/28/2011 11:55:00
# 11026         12         19   Closed      1042   7/28/2011 11:55:00
# 9845          12         19   Closed      1042   7/28/2011 11:55:00
# 34590         13         23   Closed       994   7/28/2011 12:00:00
# 37843         13         23   Closed       994   7/28/2011 12:00:00
# 63863         14         25   Closed        15   7/28/2011 12:00:00
# 60245         14         25   Closed        15   7/28/2011 12:00:00
# 37844         15         27   Closed       952   7/28/2011 12:00:00
# 9             15         27   Closed       952   7/28/2011 12:00:00
# ...          ...        ...      ...       ...                  ...
# 1161627  1579011    1748008   Closed       540  11/30/2013 21:55:00
# 1084670  1579011    1748008   Closed       540  11/30/2013 21:55:00
# 1161628  1579012    1748009   Closed      1440  11/30/2013 22:15:00
# 1549458  1579012    1748009   Closed      1440  11/30/2013 22:15:00
# 1559942  1579013    1748010   Closed       480  11/30/2013 22:25:00
# 7              ...             1971.0  Female   23    B32008
# 7              ...             1971.0  Female   23    B32008
# 8              ...             1983.0  Female   23    B32008
# 8              ...             1983.0  Female   23    B32008
# 11024          ...             1994.0    Male   47    D32010
# 9843           ...             1994.0    Male   40    D32006
# 11025          ...             1956.0    Male   47    D32010
# 9844           ...             1956.0    Male   40    D32006
# 11026          ...             1959.0  Female   47    D32010
# 9845           ...             1959.0  Female   40    D32006
# 34590          ...                NaN     NaN   47    D32010
# 37843          ...                NaN     NaN   40    D32006
# 63863          ...             1982.0    Male   22    A32010
# 60245          ...             1982.0    Male   22    A32010
# 37844          ...             1944.0    Male   40    D32006
# 9              ...             1944.0    Male   23    B32008
# ...            ...                ...     ...  ...       ...
# 1161627        ...                NaN    Male   68    M32011
# 1084670        ...                NaN    Male   76    M32012
# 1161628        ...                NaN    Male   68    M32011
# 1549458        ...                NaN    Male  130    M32021
# 1559942        ...                NaN    Male  137    M32029
# 1110402        ...                NaN    Male   74    M32018
# 1559943        ...                NaN  Female  137    M32029
# 1110403        ...                NaN  Female   74    M32018
# 1161629        ...                NaN    Male   68    M32011
# 1217805        ...                NaN    Male   67    M32006
# 1342738        ...                NaN  Female   87    M32014
# 1108728        ...                NaN  Female   74    M32018
# 1521364        ...                NaN    Male  128    M32004
# 1572026        ...                NaN    Male  136    M32027
# 1376575        ...                NaN  Female   96    M32013
# 1084671        ...                NaN  Female   76    M32012
# 1561899        ...                NaN    Male  134    M32025
# 1485503        ...                NaN    Male  139    S32006
# 1496726        ...                NaN    Male  133    M32024
# 1470226        ...                NaN    Male  129    M32015
# 1336666        ...                NaN    Male   90    M32001
# 1549459        ...                NaN    Male  130    M32021
# 1327851        ...                NaN    Male   88    M32010
# 1217806        ...                NaN    Male   67    M32006
# 1496727        ...                NaN     NaN  133    M32024
# 1559944        ...                NaN     NaN  137    M32029
# 1161630        ...                NaN    Male   68    M32011
# 1084672        ...                NaN    Male   76    M32012
# 1383944        ...                NaN  Female   95    M32007
# 1148718        ...                NaN  Female   68    M32011
#
#                                                    station   municipal  \
# 0               Mayor Thomas M. Menino - Government Center      Boston
# 0               Mayor Thomas M. Menino - Government Center      Boston
# 1               Mayor Thomas M. Menino - Government Center      Boston
# 1               Mayor Thomas M. Menino - Government Center      Boston
# 2               Mayor Thomas M. Menino - Government Center      Boston
# 2               Mayor Thomas M. Menino - Government Center      Boston
# 3               Mayor Thomas M. Menino - Government Center      Boston
# 3               Mayor Thomas M. Menino - Government Center      Boston
# 4               Mayor Thomas M. Menino - Government Center      Boston
# 4               Mayor Thomas M. Menino - Government Center      Boston
# 5               Mayor Thomas M. Menino - Government Center      Boston
# 5               Mayor Thomas M. Menino - Government Center      Boston
# 6               Mayor Thomas M. Menino - Government Center      Boston
# 6               Mayor Thomas M. Menino - Government Center      Boston
# 7               Mayor Thomas M. Menino - Government Center      Boston
# 7               Mayor Thomas M. Menino - Government Center      Boston
# 8               Mayor Thomas M. Menino - Government Center      Boston
# 8               Mayor Thomas M. Menino - Government Center      Boston
# 11024                             Cross St. at Hanover St.      Boston
# 9843                           Lewis Wharf - Atlantic Ave.      Boston
# 11025                             Cross St. at Hanover St.      Boston
# 9844                           Lewis Wharf - Atlantic Ave.      Boston
# 11026                             Cross St. at Hanover St.      Boston
# 9845                           Lewis Wharf - Atlantic Ave.      Boston
# 34590                             Cross St. at Hanover St.      Boston
# 37843                          Lewis Wharf - Atlantic Ave.      Boston
# 63863                    South Station - 700 Atlantic Ave.      Boston
# 60245                    South Station - 700 Atlantic Ave.      Boston
# 37844                          Lewis Wharf - Atlantic Ave.      Boston
# 9               Mayor Thomas M. Menino - Government Center      Boston
# ...                                                    ...         ...
# 1161627              Central Square at Mass Ave / Essex St   Cambridge
# 1084670  Central Sq Post Office / Cambridge City Hall a...   Cambridge
# 1161628              Central Square at Mass Ave / Essex St   Cambridge
# 1549458  Harvard University Gund Hall at Quincy St / Ki...   Cambridge
# 1559942                              Porter Square Station   Cambridge
# 1110402                Harvard Square at Mass Ave/ Dunster   Cambridge
# 1559943                              Porter Square Station   Cambridge
# 1110403                Harvard Square at Mass Ave/ Dunster   Cambridge
# 1161629              Central Square at Mass Ave / Essex St   Cambridge
# 1217805                       MIT at Mass Ave / Amherst St   Cambridge
# 1342738  Harvard University Housing - 115 Putnam Ave at...   Cambridge
# 1108728                Harvard Square at Mass Ave/ Dunster   Cambridge
# 1521364                               Kendall T at Main St   Cambridge
# 1572026                 Biogen Idec - Binney St / Sixth St   Cambridge
# 1376575  Cambridge Main Library at Broadway / Trowbridg...   Cambridge
# 1084671  Central Sq Post Office / Cambridge City Hall a...   Cambridge
# 1561899                             Mass Ave / Linear Park   Cambridge
# 1485503                                       Davis Square  Somerville
# 1496726  Harvard University Radcliffe Quadrangle at She...   Cambridge
# 1470226  Harvard University River Houses / Plympton St ...   Cambridge
# 1336666        Lechmere Station at Cambridge St / First St   Cambridge
# 1549459  Harvard University Gund Hall at Quincy St / Ki...   Cambridge
# 1327851      Inman Square at Vellucci Plaza / Hampshire St   Cambridge
# 1217806                       MIT at Mass Ave / Amherst St   Cambridge
# 1496727  Harvard University Radcliffe Quadrangle at She...   Cambridge
# 1559944                              Porter Square Station   Cambridge
# 1161630              Central Square at Mass Ave / Essex St   Cambridge
# 1084672  Central Sq Post Office / Cambridge City Hall a...   Cambridge
# 1383944        Cambridge St - at Columbia St / Webster Ave   Cambridge
# 1148718              Central Square at Mass Ave / Essex St   Cambridge
#
#                lat        lng  status_y origin_destination
# 0        42.359677 -71.059364   Removed             origin
# 0        42.359677 -71.059364   Removed        destination
# 1        42.359677 -71.059364   Removed             origin
# 1        42.359677 -71.059364   Removed        destination
# 2        42.359677 -71.059364   Removed             origin
# 2        42.359677 -71.059364   Removed        destination
# 3        42.359677 -71.059364   Removed             origin
# 3        42.359677 -71.059364   Removed        destination
# 4        42.359677 -71.059364   Removed             origin
# 4        42.359677 -71.059364   Removed        destination
# 5        42.359677 -71.059364   Removed             origin
# 5        42.359677 -71.059364   Removed        destination
# 6        42.359677 -71.059364   Removed        destination
# 6        42.359677 -71.059364   Removed             origin
# 7        42.359677 -71.059364   Removed        destination
# 7        42.359677 -71.059364   Removed             origin
# 8        42.359677 -71.059364   Removed             origin
# 8        42.359677 -71.059364   Removed        destination
# 11024    42.362811 -71.056067  Existing             origin
# 9843     42.363871 -71.050877  Existing        destination
# 11025    42.362811 -71.056067  Existing             origin
# 9844     42.363871 -71.050877  Existing        destination
# 11026    42.362811 -71.056067  Existing             origin
# 9845     42.363871 -71.050877  Existing        destination
# 34590    42.362811 -71.056067  Existing        destination
# 37843    42.363871 -71.050877  Existing             origin
# 63863    42.352175 -71.055547  Existing             origin
# 60245    42.352175 -71.055547  Existing        destination
# 37844    42.363871 -71.050877  Existing             origin
# 9        42.359677 -71.059364   Removed        destination
# ...            ...        ...       ...                ...
# 1161627  42.365070 -71.103100  Existing        destination
# 1084670  42.366426 -71.105495  Existing             origin
# 1161628  42.365070 -71.103100  Existing        destination
# 1549458  42.376369 -71.114025  Existing             origin
# 1559942  42.387995 -71.119084  Existing             origin
# 1110402  42.373268 -71.118579  Existing        destination
# 1559943  42.387995 -71.119084  Existing             origin
# 1110403  42.373268 -71.118579  Existing        destination
# 1161629  42.365070 -71.103100  Existing        destination
# 1217805  42.358100 -71.093198  Existing             origin
# 1342738  42.366621 -71.114214  Existing        destination
# 1108728  42.373268 -71.118579  Existing             origin
# 1521364  42.362457 -71.084970  Existing             origin
# 1572026  42.366095 -71.086388  Existing        destination
# 1376575  42.373379 -71.111075  Existing        destination
# 1084671  42.366426 -71.105495  Existing             origin
# 1561899  42.397828 -71.130516  Existing             origin
# 1485503  42.396969 -71.123024  Existing        destination
# 1496726  42.380287 -71.125107  Existing        destination
# 1470226  42.369832 -71.118201  Existing             origin
# 1336666  42.370700 -71.077110  Existing        destination
# 1549459  42.376369 -71.114025  Existing             origin
# 1327851  42.374035 -71.101427  Existing        destination
# 1217806  42.358100 -71.093198  Existing             origin
# 1496727  42.380287 -71.125107  Existing        destination
# 1559944  42.387995 -71.119084  Existing             origin
# 1161630  42.365070 -71.103100  Existing        destination
# 1084672  42.366426 -71.105495  Existing             origin
# 1383944  42.372969 -71.094445  Existing        destination
# 1148718  42.365070 -71.103100  Existing             origin
#
# [3157991 rows x 21 columns]

# %%
list=final.columns.tolist()
drop_cols=['hubway_id', 'status_x', 'duration','start_date','end_date','bike_nr','subsc_type',
 'zip_code', 'birth_date', 'gender','municipal','status_y']

# %%
final=final.drop(drop_cols,axis=1)

# %%
final.head(2)
# Out:
#    seq_id strt_statn end_statn  id terminal  \
# 0       1         23        23  23   B32008
# 1       2         23        23  23   B32008
#
#                                       station        lat        lng  \
# 0  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 1  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
#
#   origin_destination
# 0             origin
# 1             origin

# %%
final.sort_values(by='seq_id').head(2)
# Out:
#    seq_id strt_statn end_statn  id terminal  \
# 0       1         23        23  23   B32008
# 0       1         23        23  23   B32008
#
#                                       station        lat        lng  \
# 0  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 0  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
#
#   origin_destination
# 0             origin
# 0        destination

# %%
bike_data=final.drop(['strt_statn','end_statn'],axis=1)

# %%
bike_data.head(2)
# Out:
#    seq_id  id terminal                                     station        lat  \
# 0       1  23   B32008  Mayor Thomas M. Menino - Government Center  42.359677
# 1       2  23   B32008  Mayor Thomas M. Menino - Government Center  42.359677
#
#          lng origin_destination
# 0 -71.059364             origin
# 1 -71.059364             origin

# %%
#bike_data.to_csv("C:/Users/prathik/Documents/Data Science Super Specialization/Tableau/Project/bike_data.csv")

# %%
def origin_station (row):
   if row['origin_destination'] == 'origin' :
      return bike_data.station

# %%
bike_data.apply (lambda row: origin_station(row),axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-24eea1123016> in <module>()
# ----> 1 bike_data.apply (lambda row: origin_station(row),axis=1)
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4355         else:
#    4356             try:
# -> 4357                 for i, v in enumerate(series_gen):
#    4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\frame.py in <genexpr>(.0)
#    4333             series_gen = (Series.from_array(arr, index=res_columns, name=name,
#    4334                                             dtype=dtype)
# -> 4335                           for i, (arr, name) in enumerate(zip(values,
#    4336                                                               res_index)))
#    4337         else:  # pragma : no cover
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\series.py in from_array(cls, arr, index, name, dtype, copy, fastpath)
#     264
#     265         return cls(arr, index=index, name=name, dtype=dtype, copy=copy,
# --> 266                    fastpath=fastpath)
#     267
#     268     @property
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     246             else:
#     247                 data = _sanitize_array(data, index, dtype, copy,
# --> 248                                        raise_cast_failure=True)
#     249
#     250                 data = SingleBlockManager(data, index, fastpath=True)
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2899
#    2900     if dtype is not None:
# -> 2901         dtype = pandas_dtype(dtype)
#    2902
#    2903     if isinstance(data, ma.MaskedArray):
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\dtypes\common.py in pandas_dtype(dtype)
#    1863     """
#    1864
# -> 1865     if isinstance(dtype, DatetimeTZDtype):
#    1866         return dtype
#    1867     elif isinstance(dtype, PeriodDtype):
#
# KeyboardInterrupt:

# %%
origin_station=[]
for n in bike_data.origin_destination:
    if['origin_destination']=='origin':
        bike_data['origin_station']=bike_data.station

# %%
destination_station=[]
for n in bike_data.origin_destination:
    if['origin_destination']=='destination':
        bike_data['destination_station']=bike_data.station

# %%
bike_data.columns
# Out:
# Index(['seq_id', 'id', 'terminal', 'station', 'lat', 'lng',
#        'origin_destination'],
#       dtype='object')

# %%
bike_data.head(2)
# Out:
#    seq_id  id terminal                                     station        lat  \
# 0       1  23   B32008  Mayor Thomas M. Menino - Government Center  42.359677
# 1       2  23   B32008  Mayor Thomas M. Menino - Government Center  42.359677
#
#          lng origin_destination
# 0 -71.059364             origin
# 1 -71.059364             origin

# %%
bike_data['origin_station']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'origin_station'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-8c849ce0a122> in <module>()
# ----> 1 bike_data['origin_station']
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'origin_station'
