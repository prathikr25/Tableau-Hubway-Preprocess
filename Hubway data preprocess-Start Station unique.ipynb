# %%
import pandas as pd
stations=pd.read_csv("C:/Users/prathik/Documents/Data Science Super Specialization/Tableau/Project/hubway_stations.csv")

# %%
trips=pd.read_csv("C:/Users/prathik/Documents/Data Science Super Specialization/Tableau/Project/hubway_trips.csv")

# %%
trips.head()
# Out:
#    seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 0       1          8  Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9  Closed       220  7/28/2011 10:21:00        23.0
# 2       3         10  Closed        56  7/28/2011 10:33:00        23.0
# 3       4         11  Closed        64  7/28/2011 10:35:00        23.0
# 4       5         12  Closed        12  7/28/2011 10:37:00        23.0
#
#              end_date  end_statn bike_nr  subsc_type zip_code  birth_date  \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered   '97217      1976.0
# 1  7/28/2011 10:25:00       23.0  B00554  Registered   '02215      1966.0
# 2  7/28/2011 10:34:00       23.0  B00456  Registered   '02108      1943.0
# 3  7/28/2011 10:36:00       23.0  B00554  Registered   '02116      1981.0
# 4  7/28/2011 10:37:00       23.0  B00554  Registered   '97214      1983.0
#
#    gender
# 0    Male
# 1    Male
# 2    Male
# 3  Female
# 4  Female

# %%
result=trips

# %%
unique_values=[]
for n in range(1,146):
    df=result.loc[result['strt_statn'] == n]
    df=df.drop_duplicates(subset='end_statn', keep='first', inplace=False)
    unique_values.append(df)
unique_values=pd.concat(unique_values)

# %%
result = pd.merge(unique_values,
                 stations,
                 left_on='strt_statn',right_on='id')
result['origin_destination']='origin'

# %%
result.head(2)
# Out:
#    seq_id  hubway_id status_x  duration          start_date strt_statn  \
# 0      62         85   Closed        50  7/28/2011 12:31:00          3
# 1     157        187   Closed       158  7/28/2011 16:15:00          3
#
#              end_date  end_statn bike_nr  subsc_type        ...          \
# 0  7/28/2011 12:32:00        3.0  B00071  Registered        ...
# 1  7/28/2011 16:18:00       14.0  B00190  Registered        ...
#
#   birth_date  gender id  terminal                 station municipal  \
# 0     1967.0    Male  3    B32006  Colleges of the Fenway    Boston
# 1     1987.0  Female  3    B32006  Colleges of the Fenway    Boston
#
#          lat        lng  status_y origin_destination
# 0  42.340021 -71.100812  Existing             origin
# 1  42.340021 -71.100812  Existing             origin
#
# [2 rows x 21 columns]

# %%
result_1 = pd.merge(unique_values,
                 stations,
                 left_on='end_statn',right_on='id')
result_1['origin_destination']='destination'
result_1.head()
# Out:
#    seq_id  hubway_id status_x  duration          start_date  strt_statn  \
# 0      62         85   Closed        50  7/28/2011 12:31:00         3.0
# 1   38146      42152   Closed      1117  8/31/2011 08:13:00         4.0
# 2    2355       2591   Closed      3209  7/31/2011 16:17:00         5.0
# 3    1216       1353   Closed      1871  7/30/2011 13:47:00         6.0
# 4  895501    1013679   Closed      1380  6/18/2013 21:02:00         7.0
#
#              end_date end_statn bike_nr  subsc_type        ...          \
# 0  7/28/2011 12:32:00         3  B00071  Registered        ...
# 1  8/31/2011 08:32:00         3  B00071  Registered        ...
# 2  7/31/2011 17:11:00         3  B00081      Casual        ...
# 3  7/30/2011 14:19:00         3  B00488      Casual        ...
# 4  6/18/2013 21:25:00         3  T01397  Registered        ...
#
#   birth_date  gender id  terminal                 station municipal  \
# 0     1967.0    Male  3    B32006  Colleges of the Fenway    Boston
# 1     1967.0    Male  3    B32006  Colleges of the Fenway    Boston
# 2        NaN     NaN  3    B32006  Colleges of the Fenway    Boston
# 3        NaN     NaN  3    B32006  Colleges of the Fenway    Boston
# 4        NaN  Female  3    B32006  Colleges of the Fenway    Boston
#
#          lat        lng  status_y origin_destination
# 0  42.340021 -71.100812  Existing        destination
# 1  42.340021 -71.100812  Existing        destination
# 2  42.340021 -71.100812  Existing        destination
# 3  42.340021 -71.100812  Existing        destination
# 4  42.340021 -71.100812  Existing        destination
#
# [5 rows x 21 columns]

# %%
final = pd.concat([result, result_1])

# %%
final.head(2)
# Out:
#    seq_id  hubway_id status_x  duration          start_date strt_statn  \
# 0      62         85   Closed        50  7/28/2011 12:31:00          3
# 1     157        187   Closed       158  7/28/2011 16:15:00          3
#
#              end_date end_statn bike_nr  subsc_type        ...          \
# 0  7/28/2011 12:32:00         3  B00071  Registered        ...
# 1  7/28/2011 16:18:00        14  B00190  Registered        ...
#
#   birth_date  gender id  terminal                 station municipal  \
# 0     1967.0    Male  3    B32006  Colleges of the Fenway    Boston
# 1     1987.0  Female  3    B32006  Colleges of the Fenway    Boston
#
#          lat        lng  status_y origin_destination
# 0  42.340021 -71.100812  Existing             origin
# 1  42.340021 -71.100812  Existing             origin
#
# [2 rows x 21 columns]

# %%
final.sort_values(by='seq_id')
# Out:
#         seq_id  hubway_id status_x  duration           start_date strt_statn  \
# 2510         1          8   Closed         9   7/28/2011 10:12:00         23
# 3987         1          8   Closed         9   7/28/2011 10:12:00         23
# 4366        10         17   Closed      1108   7/28/2011 11:55:00         47
# 5239        10         17   Closed      1108   7/28/2011 11:55:00         47
# 4337        13         23   Closed       994   7/28/2011 12:00:00         40
# 5316        13         23   Closed       994   7/28/2011 12:00:00         40
# 2373        14         25   Closed        15   7/28/2011 12:00:00         22
# 661         14         25   Closed        15   7/28/2011 12:00:00         22
# 4003        15         27   Closed       952   7/28/2011 12:00:00         40
# 4338        15         27   Closed       952   7/28/2011 12:00:00         40
# 1053        17         29   Closed      1261   7/28/2011 12:00:00         22
# 2374        17         29   Closed      1261   7/28/2011 12:00:00         22
# 4116        19         31   Closed      1020   7/28/2011 12:01:00         38
# 1204        19         31   Closed      1020   7/28/2011 12:01:00         38
# 4117        20         33   Closed      1264   7/28/2011 12:01:00         38
# 3247        20         33   Closed      1264   7/28/2011 12:01:00         38
# 3232        22         35   Closed       969   7/28/2011 12:01:00         22
# 2375        22         35   Closed       969   7/28/2011 12:01:00         22
# 4722        23         37   Closed      1582   7/28/2011 12:01:00         38
# 4118        23         37   Closed      1582   7/28/2011 12:01:00         38
# 6910        24         38   Closed       620   7/28/2011 12:01:00         22
# 2376        24         38   Closed       620   7/28/2011 12:01:00         22
# 4119        26         41   Closed       771   7/28/2011 12:02:00         38
# 808         26         41   Closed       771   7/28/2011 12:02:00         38
# 2377        30         45   Closed       824   7/28/2011 12:02:00         22
# 4969        30         45   Closed       824   7/28/2011 12:02:00         22
# 2510      1976.0    Male   23    B32008
# 3987      1976.0    Male   23    B32008
# 4366      1994.0    Male   40    D32006
# 5239      1994.0    Male   47    D32010
# 4337         NaN     NaN   40    D32006
# 5316         NaN     NaN   47    D32010
# 2373      1982.0    Male   22    A32010
# 661       1982.0    Male   22    A32010
# 4003      1944.0    Male   23    B32008
# 4338      1944.0    Male   40    D32006
# 1053      1975.0    Male   45    B32011
# 2374      1975.0    Male   22    A32010
# 4116      1987.0  Female   38    D32003
# 1204      1987.0  Female   36    D32005
# 4117      1985.0  Female   38    D32003
# 3247      1985.0  Female   44    D32009
# 3232      1971.0    Male   44    D32009
# 2375      1971.0    Male   22    A32010
# 4722      1980.0  Female   10    A32003
# 4118      1980.0  Female   38    D32003
# 6910      1955.0  Female   20    B32004
# 2376      1955.0  Female   22    A32010
# 4119      1943.0    Male   38    D32003
# 808       1943.0    Male   42    D32007
# 2377      1967.0    Male   22    A32010
# 4969      1967.0    Male   38    D32003
# 5314      1975.0  Female   47    D32010
# 4120      1975.0  Female   38    D32003
# 2378      1982.0    Male   22    A32010
# 402       1982.0    Male   25    A32009
# ...          ...     ...  ...       ...
# 13489        NaN  Female  126    K32002
# 13670        NaN  Female  123    E32004
# 10638        NaN     NaN   92    C32014
# 10235        NaN     NaN   99    B32008
# 640          NaN    Male    7    A32000
# 14154        NaN    Male  119    D32027
# 14427        NaN    Male  135    M32026
# 13751        NaN    Male  101    B32020
# 14151        NaN    Male  119    D32027
# 262          NaN    Male    4    C32000
# 13646        NaN     NaN  123    E32004
# 5238         NaN     NaN   46    B32005
# 15123        NaN    Male  142    S32009
# 6746         NaN    Male   58    D32017
# 8696         NaN    Male   69    K32001
# 14526        NaN    Male  136    M32027
# 14186        NaN     NaN  119    D32027
# 7292         NaN     NaN   63    C32009
# 13053        NaN    Male  119    D32027
# 6085         NaN    Male   63    C32009
# 14211        NaN    Male  119    D32027
# 12658        NaN    Male  114    D32022
# 11579        NaN    Male  131    M32022
# 13054        NaN    Male  119    D32027
# 13055        NaN    Male  119    D32027
# 11461        NaN    Male   96    M32013
# 10800        NaN    Male   88    M32010
# 13599        NaN    Male  127    K32004
# 4042         NaN    Male   36    D32005
# 13643        NaN    Male  123    E32004
#
#                                                  station   municipal  \
# 2510          Mayor Thomas M. Menino - Government Center      Boston
# 3987          Mayor Thomas M. Menino - Government Center      Boston
# 4366                         Lewis Wharf - Atlantic Ave.      Boston
# 5239                            Cross St. at Hanover St.      Boston
# 4337                         Lewis Wharf - Atlantic Ave.      Boston
# 5316                            Cross St. at Hanover St.      Boston
# 2373                   South Station - 700 Atlantic Ave.      Boston
# 661                    South Station - 700 Atlantic Ave.      Boston
# 4003          Mayor Thomas M. Menino - Government Center      Boston
# 4338                         Lewis Wharf - Atlantic Ave.      Boston
# 1053                          Yawkey Way at Boylston St.      Boston
# 2374                   South Station - 700 Atlantic Ave.      Boston
# 4116                             TD Garden - Legends Way      Boston
# 1204            Boston Public Library - 700 Boylston St.      Boston
# 4117                             TD Garden - Legends Way      Boston
# 3247               Faneuil Hall - Union St. at North St.      Boston
# 3232               Faneuil Hall - Union St. at North St.      Boston
# 2375                   South Station - 700 Atlantic Ave.      Boston
# 4722                       B.U. Central - 725 Comm. Ave.      Boston
# 4118                             TD Garden - Legends Way      Boston
# 6910                Aquarium Station - 200 Atlantic Ave.      Boston
# 2376                   South Station - 700 Atlantic Ave.      Boston
# 4119                             TD Garden - Legends Way      Boston
# 808                        Boylston St. at Arlington St.      Boston
# 2377                   South Station - 700 Atlantic Ave.      Boston
# 4969                             TD Garden - Legends Way      Boston
# 5314                            Cross St. at Hanover St.      Boston
# 4120                             TD Garden - Legends Way      Boston
# 2378                   South Station - 700 Atlantic Ave.      Boston
# 402                             Tremont St / W Newton St      Boston
# ...                                                  ...         ...
# 13489   Washington Square at Washington St. / Beacon St.   Brookline
# 13670                    Egleston Square at Columbus Ave      Boston
# 10638                 University of Massachusetts Boston      Boston
# 10235         Mayor Thomas M. Menino - Government Center      Boston
# 640                                             Fan Pier      Boston
# 14154          New Balance Store - Boylston at Dartmouth      Boston
# 14427          359 Broadway - Broadway at Fayette Street   Cambridge
# 13751                 BIDMC - Brookline at Burlington St      Boston
# 14151          New Balance Store - Boylston at Dartmouth      Boston
# 262                          Tremont St. at Berkeley St.      Boston
# 13646                    Egleston Square at Columbus Ave      Boston
# 5238                             Christian Science Plaza      Boston
# 15123                     Packard Ave / Powderhouse Blvd  Somerville
# 6746         The Esplanade - Beacon St. at Arlington St.      Boston
# 8696             Coolidge Corner - Beacon St @ Centre St   Brookline
# 14526                 Biogen Idec - Binney St / Sixth St   Cambridge
# 14186          New Balance Store - Boylston at Dartmouth      Boston
# 7292                    Dorchester Ave. at Gillette Park      Boston
# 13053          New Balance Store - Boylston at Dartmouth      Boston
# 6085                    Dorchester Ave. at Gillette Park      Boston
# 14211          New Balance Store - Boylston at Dartmouth      Boston
# 12658             TD Garden - Causeway at Portal Park #1      Boston
# 11579    Lower Cambridgeport at Magazine St/Riverside Rd   Cambridge
# 13054          New Balance Store - Boylston at Dartmouth      Boston
# 13055          New Balance Store - Boylston at Dartmouth      Boston
# 11461  Cambridge Main Library at Broadway / Trowbridg...   Cambridge
# 10800      Inman Square at Vellucci Plaza / Hampshire St   Cambridge
# 13599        JFK Crossing at Harvard St. / Thorndike St.   Brookline
# 4042            Boston Public Library - 700 Boylston St.      Boston
# 13643                    Egleston Square at Columbus Ave      Boston
#
#              lat        lng  status_y origin_destination
# 2510   42.359677 -71.059364   Removed             origin
# 3987   42.359677 -71.059364   Removed        destination
# 4366   42.363871 -71.050877  Existing        destination
# 5239   42.362811 -71.056067  Existing             origin
# 4337   42.363871 -71.050877  Existing             origin
# 5316   42.362811 -71.056067  Existing        destination
# 2373   42.352175 -71.055547  Existing             origin
# 661    42.352175 -71.055547  Existing        destination
# 4003   42.359677 -71.059364   Removed        destination
# 4338   42.363871 -71.050877  Existing             origin
# 1053   42.344763 -71.097880  Existing        destination
# 2374   42.352175 -71.055547  Existing             origin
# 4116   42.366231 -71.060868   Removed             origin
# 1204   42.349673 -71.077303  Existing        destination
# 4117   42.366231 -71.060868   Removed             origin
# 3247   42.360583 -71.056868  Existing        destination
# 3232   42.360583 -71.056868  Existing        destination
# 2375   42.352175 -71.055547  Existing             origin
# 4722   42.350075 -71.105884  Existing        destination
# 4118   42.366231 -71.060868   Removed             origin
# 6910   42.359770 -71.051601  Existing        destination
# 2376   42.352175 -71.055547  Existing             origin
# 4119   42.366231 -71.060868   Removed             origin
# 808    42.352096 -71.070378  Existing        destination
# 2377   42.352175 -71.055547  Existing             origin
# 4969   42.366231 -71.060868   Removed        destination
# 5314   42.362811 -71.056067  Existing        destination
# 4120   42.366231 -71.060868   Removed             origin
# 2378   42.352175 -71.055547  Existing             origin
# 402    42.341332 -71.076847  Existing        destination
# ...          ...        ...       ...                ...
# 13489  42.339335 -71.134930  Existing             origin
# 13670  42.315692 -71.098634  Existing        destination
# 10638  42.311819 -71.035705  Existing             origin
# 10235  42.358920 -71.057629  Existing        destination
# 640    42.353412 -71.044624  Existing             origin
# 14154  42.350413 -71.076550  Existing        destination
# 14427  42.370803 -71.104412  Existing             origin
# 13751  42.345733 -71.100694  Existing        destination
# 14151  42.350413 -71.076550  Existing        destination
# 262    42.345392 -71.069616  Existing             origin
# 13646  42.315692 -71.098634  Existing        destination
# 5238   42.343864 -71.085918  Existing             origin
# 15123  42.404490 -71.123413  Existing        destination
# 6746   42.355596 -71.072780  Existing             origin
# 8696   42.341598 -71.123338  Existing        destination
# 14526  42.366095 -71.086388  Existing             origin
# 14186  42.350413 -71.076550  Existing        destination
# 7292   42.344023 -71.057054  Existing             origin
# 13053  42.350413 -71.076550  Existing             origin
# 6085   42.344023 -71.057054  Existing        destination
# 14211  42.350413 -71.076550  Existing        destination
# 12658  42.365942 -71.060515  Existing             origin
# 11579  42.356954 -71.113687  Existing        destination
# 13054  42.350413 -71.076550  Existing             origin
# 13055  42.350413 -71.076550  Existing             origin
# 11461  42.373379 -71.111075  Existing        destination
# 10800  42.374035 -71.101427  Existing        destination
# 13599  42.346563 -71.128374  Existing             origin
# 4042   42.349673 -71.077303  Existing             origin
# 13643  42.315692 -71.098634  Existing        destination
#
# [30494 rows x 21 columns]

# %%
list=final.columns.tolist()
drop_cols=['hubway_id', 'status_x', 'duration','start_date','end_date','bike_nr','subsc_type',
 'zip_code', 'birth_date', 'gender','municipal','status_y']

# %%
final=final.drop(drop_cols,axis=1)

# %%
final.head(2)
# Out:
#    seq_id strt_statn end_statn  id terminal                 station  \
# 0      62          3         3   3   B32006  Colleges of the Fenway
# 1     157          3        14   3   B32006  Colleges of the Fenway
#
#          lat        lng origin_destination
# 0  42.340021 -71.100812             origin
# 1  42.340021 -71.100812             origin

# %%
final.sort_values(by='seq_id').head(2)
# Out:
#       seq_id strt_statn end_statn  id terminal  \
# 2510       1         23        23  23   B32008
# 3987       1         23        23  23   B32008
#
#                                          station        lat        lng  \
# 2510  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 3987  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
#
#      origin_destination
# 2510             origin
# 3987        destination

# %%
bike_data=final.drop(['strt_statn','end_statn'],axis=1)

# %%
bike_data.head(2)
# Out:
#    seq_id  id terminal                 station        lat        lng  \
# 0      62   3   B32006  Colleges of the Fenway  42.340021 -71.100812
# 1     157   3   B32006  Colleges of the Fenway  42.340021 -71.100812
#
#   origin_destination
# 0             origin
# 1             origin

# %%
bike_data.to_csv("C:/Users/prathik/Documents/Data Science Super Specialization/Tableau/Project/bike_data_unique.csv")

# %%
'''def origin_station (row):
   if row['origin_destination'] == 'origin' :
      return bike_data.station'''

# %%
#bike_data.apply (lambda row: origin_station(row),axis=1)

# %%
'''origin_station=[]
for n in bike_data.origin_destination:
    if['origin_destination']=='origin':
        bike_data['origin_station']=bike_data.station'''

# %%
'''destination_station=[]
for n in bike_data.origin_destination:
    if['origin_destination']=='destination':
        bike_data['destination_station']=bike_data.station'''

# %%
#bike_data.columns
# Out:
# Index(['seq_id', 'id', 'terminal', 'station', 'lat', 'lng',
#        'origin_destination'],
#       dtype='object')

# %%
#bike_data.head(2)
# Out:
#    seq_id  id terminal                                     station        lat  \
# 0       1  23   B32008  Mayor Thomas M. Menino - Government Center  42.359677
# 1       2  23   B32008  Mayor Thomas M. Menino - Government Center  42.359677
#
#          lng origin_destination
# 0 -71.059364             origin
# 1 -71.059364             origin

# %%
#bike_data['origin_station']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'origin_station'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-8c849ce0a122> in <module>()
# ----> 1 bike_data['origin_station']
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\prathik\Anaconda3.6\envs\Tableau-Python-Server\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'origin_station'
